# %% [markdown]
# # Exploring the HERE API

# %% [markdown]
# ### 0 - Loading config

# %%
import yaml

with open("config.yml", 'r') as stream:
    try:
        cfg = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

here_id = cfg["here_api"]["here_id"]
here_passwd = cfg["here_api"]["here_passwd"]

# %% [markdown]
# ### 1 - Using HerePy - Python wrapper
# Refer to https://pypi.org/project/herepy/

# %%
import herepy
import json

geocoderApi = herepy.GeocoderApi(here_id, here_passwd)

geocoderReverseApi = herepy.GeocoderReverseApi(here_id, here_passwd)

routingApi = herepy.public_transit_api.PublicTransitApi(here_id, here_passwd)

# %%
response = geocoderApi.free_form('111 Charles Sunnyvale CA')
response.as_dict()
# Out:
# {'Response': {'MetaInfo': {'Timestamp': '2019-07-21T00:38:13.476+0000'},
#   'View': [{'_type': 'SearchResultsViewType',
#     'ViewId': 0,
#     'Result': [{'Relevance': 1.0,
#       'MatchLevel': 'houseNumber',
#       'MatchQuality': {'State': 1.0,
#        'City': 1.0,
#        'Street': [0.85],
#        'HouseNumber': 1.0},
#       'MatchType': 'pointAddress',
#       'Location': {'LocationId': 'NT_IzBye2Ci6AxGOwUQZ2yXeD_xETM',
#        'LocationType': 'point',
#        'DisplayPosition': {'Latitude': 37.37947, 'Longitude': -122.03485},
#        'NavigationPosition': [{'Latitude': 37.37944, 'Longitude': -122.03471}],
#        'MapView': {'TopLeft': {'Latitude': 37.3805942,
#          'Longitude': -122.0362647},
#         'BottomRight': {'Latitude': 37.3783458, 'Longitude': -122.0334353}},
#        'Address': {'Label': '111 Charles St, Sunnyvale, CA 94086, United States',
#         'Country': 'USA',
#         'State': 'CA',
#         'County': 'Santa Clara',
#         'City': 'Sunnyvale',
#         'District': 'Sunnyvale West',
#         'Street': 'Charles St',
#         'HouseNumber': '111',
#         'PostalCode': '94086',
#         'AdditionalData': [{'value': 'United States', 'key': 'CountryName'},
#          {'value': 'California', 'key': 'StateName'},
#          {'value': 'Santa Clara', 'key': 'CountyName'},
#          {'value': 'N', 'key': 'PostalCodeType'}]}}},
#      {'Relevance': 1.0,
#       'MatchLevel': 'houseNumber',
#       'MatchQuality': {'State': 1.0,
#        'City': 1.0,
#        'Street': [0.85],
#        'HouseNumber': 1.0},
#       'MatchType': 'pointAddress',
#       'Location': {'LocationId': 'NT_q28F72Isr2uFPJBqN92BDD_xETM',
#        'LocationType': 'point',
#        'DisplayPosition': {'Latitude': 37.37947, 'Longitude': -122.03485},
#        'NavigationPosition': [{'Latitude': 37.37944, 'Longitude': -122.03471}],
#        'MapView': {'TopLeft': {'Latitude': 37.3805942,
#          'Longitude': -122.0362647},
#         'BottomRight': {'Latitude': 37.3783458, 'Longitude': -122.0334353}},
#        'Address': {'Label': '111 Charles Ave, Sunnyvale, CA 94086, United States',
#         'Country': 'USA',
#         'State': 'CA',
#         'County': 'Santa Clara',
#         'City': 'Sunnyvale',
#         'District': 'Sunnyvale West',
#         'Street': 'Charles Ave',
#         'HouseNumber': '111',
#         'PostalCode': '94086',
#         'AdditionalData': [{'value': 'United States', 'key': 'CountryName'},
#          {'value': 'California', 'key': 'StateName'},
#          {'value': 'Santa Clara', 'key': 'CountyName'},
#          {'value': 'N', 'key': 'PostalCodeType'}]}}}]}]}}

# %%
response = geocoderReverseApi.retrieve_addresses([42.3952, -71.1056])
response.as_dict()
# Out:
# {'Response': {'MetaInfo': {'Timestamp': '2019-07-21T04:15:05.547+0000',
#    'NextPageInformation': '2'},
#   'View': [{'_type': 'SearchResultsViewType',
#     'ViewId': 0,
#     'Result': [{'Relevance': 1.0,
#       'Distance': 2.0,
#       'MatchLevel': 'houseNumber',
#       'MatchQuality': {'Country': 1.0,
#        'State': 1.0,
#        'County': 1.0,
#        'City': 1.0,
#        'District': 1.0,
#        'Street': [1.0],
#        'HouseNumber': 1.0,
#        'PostalCode': 1.0},
#       'MatchType': 'interpolated',
#       'Location': {'LocationId': 'NT_H76dmNv1jpqd.23LG3uGfD_xQD',
#        'LocationType': 'address',
#        'DisplayPosition': {'Latitude': 42.3951, 'Longitude': -71.10549},
#        'NavigationPosition': [{'Latitude': 42.39519, 'Longitude': -71.10562}],
#        'MapView': {'TopLeft': {'Latitude': 42.3962242,
#          'Longitude': -71.1070122},
#         'BottomRight': {'Latitude': 42.3939758, 'Longitude': -71.1039678}},
#        'Address': {'Label': '14 Nashua St, Somerville, MA 02145, United States',
#         'Country': 'USA',
#         'State': 'MA',
#         'County': 'Middlesex',
#         'City': 'Somerville',
#         'District': 'Magoun Square',
#         'Street': 'Nashua St',
#         'HouseNumber': '14',
#         'PostalCode': '02145',
#         'AdditionalData': [{'value': 'United States', 'key': 'CountryName'},
#          {'value': 'Massachusetts', 'key': 'StateName'},
#          {'value': 'Middlesex', 'key': 'CountyName'},
#          {'value': 'N', 'key': 'PostalCodeType'}]},
#        'MapReference': {'ReferenceId': '21973951',
#         'MapId': 'NAAM19117',
#         'MapVersion': 'Q1/2019',
#         'MapReleaseDate': '2019-07-03',
#         'Spot': 0.28,
#         'SideOfStreet': 'right',
#         'CountryId': '21000001',
#         'StateId': '21014299',
#         'CountyId': '21014501',
#         'CityId': '21014549',
#         'AddressId': '760284920',
#         'RoadLinkId': '91049726'}}}]}]}}

# %%
start_point = geocoderApi.free_form('111 Charles Sunnyvale CA')
end_point = geocoderApi.free_form('200 Charles Sunnyvale CA')

# %%
start_pos = [37.37947, -122.03485]
end_pos   = [37.38847, -122.04485]
time = '2019-07-20T12:00:00'
response = routingApi.calculate_route(start_pos, end_pos, time)

response.as_dict()
# Out:
# {'Res': {'serviceUrl': 'http://internal-ptkernel-cit-v644-1926070416.us-east-1.elb.amazonaws.com/goroute/CALIFORNIA_NEVADA_W001452_20190719',
#   'Connections': {'valid_until': '2018-09-23',
#    'context': '1aGPH8EOk03v38NteA6TTf__AAAgEzNdEv0C_9AHZADACTNdEv0',
#    'Connection': [{'id': 'R000636-C0',
#      'duration': 'PT19M',
#      'transfers': 0,
#      'Dep': {'time': '2019-07-20T12:13:00',
#       'Addr': {'y': 37.37947, 'x': -122.03485}},
#      'Arr': {'time': '2019-07-20T12:32:00',
#       'Addr': {'y': 37.38847, 'x': -122.04485}},
#      'Sections': {'Sec': [{'id': 'R000636-C0-S0',
#         'mode': 20,
#         'Dep': {'time': '2019-07-20T12:13:00',
#          'Addr': {'y': 37.37947, 'x': -122.03485},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 380, 'duration': 'PT06M'},
#         'Arr': {'time': '2019-07-20T12:19:00',
#          'Stn': {'y': 37.378179,
#           'x': -122.03113,
#           'name': 'Evelyn & Frances',
#           'id': '401901523'}}},
#        {'id': 'R000636-C0-S1',
#         'mode': 5,
#         'Dep': {'time': '2019-07-20T12:19:00',
#          'Stn': {'y': 37.378179,
#           'x': -122.03113,
#           'name': 'Evelyn & Frances',
#           'id': '401901523'},
#          'Transport': {'mode': 5,
#           'dir': '32 San Antonio Shopping Ctr',
#           'name': '32',
#           'At': {'category': 'Bus',
#            'color': '#29588C',
#            'textColor': '#FFFFFF',
#            'operator': '1wI0SC00'}}},
#         'Journey': {'distance': 2999,
#          'duration': 'PT05M',
#          'Stop': [{'dep': '2019-07-20T12:19:00',
#            'Stn': {'y': 37.378179,
#             'x': -122.03113,
#             'name': 'Evelyn & Frances',
#             'id': '401901523'}},
#           {'dep': '2019-07-20T12:20:00',
#            'Stn': {'y': 37.382533,
#             'x': -122.03239,
#             'name': 'Mathilda & California',
#             'id': '401901575'}},
#           {'dep': '2019-07-20T12:20:00',
#            'Stn': {'y': 37.385932,
#             'x': -122.03134,
#             'name': 'Mathilda & Indio',
#             'id': '401903729'}},
#           {'dep': '2019-07-20T12:23:00',
#            'Stn': {'y': 37.386932,
#             'x': -122.04315,
#             'name': 'Central & Mary',
#             'id': '401903307'}},
#           {'arr': '2019-07-20T12:24:00',
#            'Stn': {'y': 37.390844,
#             'x': -122.04814,
#             'name': 'Middlefield & Bernardo',
#             'id': '401903308'}}]},
#         'Arr': {'time': '2019-07-20T12:24:00',
#          'Stn': {'y': 37.390844,
#           'x': -122.04814,
#           'name': 'Middlefield & Bernardo',
#           'id': '401903308'}}},
#        {'id': 'R000636-C0-S2',
#         'mode': 20,
#         'Dep': {'time': '2019-07-20T12:24:00',
#          'Stn': {'y': 37.390844,
#           'x': -122.04814,
#           'name': 'Middlefield & Bernardo',
#           'id': '401903308'},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 466, 'duration': 'PT08M'},
#         'Arr': {'time': '2019-07-20T12:32:00',
#          'Addr': {'y': 37.38847, 'x': -122.04485}}}]},
#      'Tariff': {'Fares': [{'Fare': [{'name': 'Single Ride, with no transfer, VTA',
#           'price': 2.5,
#           'currency': 'USD',
#           'sec_ids': 'R000636-C0-S1'}]}]}},
#     {'id': 'R000636-C1',
#      'duration': 'PT19M',
#      'transfers': 0,
#      'Dep': {'time': '2019-07-20T13:12:00',
#       'Addr': {'y': 37.37947, 'x': -122.03485}},
#      'Arr': {'time': '2019-07-20T13:31:00',
#       'Addr': {'y': 37.38847, 'x': -122.04485}},
#      'Sections': {'Sec': [{'id': 'R000636-C1-S0',
#         'mode': 20,
#         'Dep': {'time': '2019-07-20T13:12:00',
#          'Addr': {'y': 37.37947, 'x': -122.03485},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 380, 'duration': 'PT06M'},
#         'Arr': {'time': '2019-07-20T13:18:00',
#          'Stn': {'y': 37.378179,
#           'x': -122.03113,
#           'name': 'Evelyn & Frances',
#           'id': '401901523'}}},
#        {'id': 'R000636-C1-S1',
#         'mode': 5,
#         'Dep': {'time': '2019-07-20T13:18:00',
#          'Stn': {'y': 37.378179,
#           'x': -122.03113,
#           'name': 'Evelyn & Frances',
#           'id': '401901523'},
#          'Transport': {'mode': 5,
#           'dir': '32 San Antonio Shopping Ctr',
#           'name': '32',
#           'At': {'category': 'Bus',
#            'color': '#29588C',
#            'textColor': '#FFFFFF',
#            'operator': '1wI0SC00'}}},
#         'Journey': {'distance': 2999,
#          'duration': 'PT05M',
#          'Stop': [{'dep': '2019-07-20T13:18:00',
#            'Stn': {'y': 37.378179,
#             'x': -122.03113,
#             'name': 'Evelyn & Frances',
#             'id': '401901523'}},
#           {'dep': '2019-07-20T13:19:00',
#            'Stn': {'y': 37.382533,
#             'x': -122.03239,
#             'name': 'Mathilda & California',
#             'id': '401901575'}},
#           {'dep': '2019-07-20T13:19:00',
#            'Stn': {'y': 37.385932,
#             'x': -122.03134,
#             'name': 'Mathilda & Indio',
#             'id': '401903729'}},
#           {'dep': '2019-07-20T13:22:00',
#            'Stn': {'y': 37.386932,
#             'x': -122.04315,
#             'name': 'Central & Mary',
#             'id': '401903307'}},
#           {'arr': '2019-07-20T13:23:00',
#            'Stn': {'y': 37.390844,
#             'x': -122.04814,
#             'name': 'Middlefield & Bernardo',
#             'id': '401903308'}}]},
#         'Arr': {'time': '2019-07-20T13:23:00',
#          'Stn': {'y': 37.390844,
#           'x': -122.04814,
#           'name': 'Middlefield & Bernardo',
#           'id': '401903308'}}},
#        {'id': 'R000636-C1-S2',
#         'mode': 20,
#         'Dep': {'time': '2019-07-20T13:23:00',
#          'Stn': {'y': 37.390844,
#           'x': -122.04814,
#           'name': 'Middlefield & Bernardo',
#           'id': '401903308'},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 466, 'duration': 'PT08M'},
#         'Arr': {'time': '2019-07-20T13:31:00',
#          'Addr': {'y': 37.38847, 'x': -122.04485}}}]},
#      'Tariff': {'Fares': [{'Fare': [{'name': 'Single Ride, with no transfer, VTA',
#           'price': 2.5,
#           'currency': 'USD',
#           'sec_ids': 'R000636-C1-S1'}]}]}},
#     {'id': 'R000636-C2',
#      'duration': 'PT01H07M',
#      'transfers': 1,
#      'Dep': {'time': '2019-07-20T12:19:00',
#       'Addr': {'y': 37.37947, 'x': -122.03485}},
#      'Arr': {'time': '2019-07-20T13:26:00',
#       'Addr': {'y': 37.38847, 'x': -122.04485}},
#      'Sections': {'Sec': [{'id': 'R000636-C2-S0',
#         'mode': 20,
#         'Dep': {'time': '2019-07-20T12:19:00',
#          'Addr': {'y': 37.37947, 'x': -122.03485},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 567, 'duration': 'PT09M'},
#         'Arr': {'time': '2019-07-20T12:28:00',
#          'Stn': {'y': 37.382533,
#           'x': -122.03239,
#           'name': 'Mathilda & California',
#           'id': '401901575'}}},
#        {'id': 'R000636-C2-S1',
#         'mode': 5,
#         'Dep': {'time': '2019-07-20T12:28:00',
#          'Stn': {'y': 37.382533,
#           'x': -122.03239,
#           'name': 'Mathilda & California',
#           'id': '401901575'},
#          'Transport': {'mode': 5,
#           'dir': '54 Lockheed Martin',
#           'name': '54',
#           'At': {'category': 'Bus',
#            'color': '#29588C',
#            'textColor': '#FFFFFF',
#            'operator': '1wI0SC00'}}},
#         'Journey': {'distance': 3344,
#          'duration': 'PT10M',
#          'Stop': [{'dep': '2019-07-20T12:28:00',
#            'Stn': {'y': 37.382533,
#             'x': -122.03239,
#             'name': 'Mathilda & California',
#             'id': '401901575'}},
#           {'dep': '2019-07-20T12:30:00',
#            'Stn': {'y': 37.386732,
#             'x': -122.03104,
#             'name': 'Mathilda & Indio',
#             'id': '401901576'}},
#           {'dep': '2019-07-20T12:31:00',
#            'Stn': {'y': 37.390237,
#             'x': -122.03022,
#             'name': 'Mathilda & Maude',
#             'id': '401901577'}},
#           {'dep': '2019-07-20T12:32:00',
#            'Stn': {'y': 37.394217,
#             'x': -122.02896,
#             'name': 'Mathilda & San Aleso',
#             'id': '401901578'}},
#           {'dep': '2019-07-20T12:34:00',
#            'Stn': {'y': 37.401423,
#             'x': -122.02683,
#             'name': 'Mathilda & Ross',
#             'id': '401901579'}},
#           {'dep': '2019-07-20T12:36:00',
#            'Stn': {'y': 37.405951,
#             'x': -122.02588,
#             'name': 'Mathilda & Moffett Park',
#             'id': '401901580'}},
#           {'arr': '2019-07-20T12:38:00',
#            'Stn': {'y': 37.410483,
#             'x': -122.02811,
#             'name': 'Lockheed Martin Transit Center',
#             'id': '401901581'}}]},
#         'Arr': {'time': '2019-07-20T12:38:00',
#          'Stn': {'y': 37.410483,
#           'x': -122.02811,
#           'name': 'Lockheed Martin Transit Center',
#           'id': '401901581'}}},
#        {'id': 'R000636-C2-S2',
#         'mode': 20,
#         'Dep': {'time': '2019-07-20T12:38:00',
#          'Stn': {'y': 37.410483,
#           'x': -122.02811,
#           'name': 'Lockheed Martin Transit Center',
#           'id': '401901581'},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 494, 'duration': 'PT10M'},
#         'Arr': {'time': '2019-07-20T12:48:00',
#          'Stn': {'y': 37.409404,
#           'x': -122.02713,
#           'name': 'Lockheed Martin Station (0)',
#           'id': '401903948'}}},
#        {'id': 'R000636-C2-S3',
#         'mode': 8,
#         'Dep': {'time': '2019-07-20T13:00:00',
#          'Stn': {'y': 37.409404,
#           'x': -122.02713,
#           'name': 'Lockheed Martin Station (0)',
#           'id': '401903948'},
#          'Transport': {'mode': 8,
#           'dir': 'Mountain View',
#           'name': '902',
#           'At': {'category': 'Tram',
#            'color': '#99CC66',
#            'textColor': '#000000',
#            'operator': '1wI0SC00'}},
#          'Freq': {'min': 15,
#           'max': 15,
#           'AltDep': [{'time': '2019-07-20T13:15:00',
#             'Transport': {'mode': 8,
#              'dir': 'Mountain View',
#              'name': '914',
#              'At': {'category': 'Tram',
#               'color': '#29588C',
#               'textColor': '#FFFFFF',
#               'operator': '1wI0SC00'}}}]}},
#         'Journey': {'distance': 3987,
#          'duration': 'PT07M',
#          'Stop': [{'dep': '2019-07-20T13:00:00',
#            'Stn': {'y': 37.409404,
#             'x': -122.02713,
#             'name': 'Lockheed Martin Station (0)',
#             'id': '401903948'}},
#           {'dep': '2019-07-20T13:02:00',
#            'Stn': {'y': 37.402439,
#             'x': -122.03433,
#             'name': 'Moffett Park Station (0)',
#             'id': '401907610'}},
#           {'dep': '2019-07-20T13:04:00',
#            'Stn': {'y': 37.404703,
#             'x': -122.04998,
#             'name': 'Bayshore Nasa Station (0)',
#             'id': '401903949'}},
#           {'arr': '2019-07-20T13:07:00',
#            'Stn': {'y': 37.395428,
#             'x': -122.0522,
#             'name': 'Middlefield Station (0)',
#             'id': '401907997'}}]},
#         'Arr': {'time': '2019-07-20T13:07:00',
#          'Stn': {'y': 37.395428,
#           'x': -122.0522,
#           'name': 'Middlefield Station (0)',
#           'id': '401907997'}}},
#        {'id': 'R000636-C2-S4',
#         'mode': 20,
#         'Dep': {'time': '2019-07-20T13:07:00',
#          'Stn': {'y': 37.395428,
#           'x': -122.0522,
#           'name': 'Middlefield Station (0)',
#           'id': '401907997'},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 1120, 'duration': 'PT19M'},
#         'Arr': {'time': '2019-07-20T13:26:00',
#          'Addr': {'y': 37.38847, 'x': -122.04485}}}]},
#      'Tariff': {'Fares': [{'Fare': [{'name': 'Single Ride, with no transfer, VTA',
#           'price': 2.5,
#           'currency': 'USD',
#           'sec_ids': 'R000636-C2-S1'},
#          {'name': 'Single Ride, VTA',
#           'price': 2.5,
#           'currency': 'USD',
#           'sec_ids': 'R000636-C2-S3'}]}]}}],
#    'Operators': {'Op': [{'code': '1wI0SC00',
#       'type': 'TT',
#       'name': 'VTA',
#       'short_name': 'SC',
#       'Link': [{'type': 'website',
#         'href': 'https://cit.transit.api.here.com/r?appId=Pt3AjURCavWv8DLkK9KX&u=http://www.vta.org',
#         'sec_ids': 'R000636-C0-S1 R000636-C1-S1 R000636-C2-S1 R000636-C2-S3',
#         'text': 'VTA'}],
#       'At': {'phone': '408-321-2300'}}]}}}}

# %% [markdown]
# ### 2 - Using Requests

# %%
import requests

# %%
PARAMS = {'app_id': here_id,
          'app_code': here_passwd,
          'dep':"42.59452409,-87.825373057",
          'arr':"41.86851845,-87.657831553",
          'time':"2019-11-24T07:30:00"}

response = requests.get('https://mobility.api.here.com/v1/route.json', params=PARAMS)

# %%
PARAMS = {'app_id': here_id,
          'app_code': here_passwd,
          'dep':"37.869840, -122.252232",
          'arr':"37.793212, -122.396487",
          'time':"2019-08-22T07:30:00"}

response = requests.get('https://mobility.api.here.com/v1/route.json', params=PARAMS)

# %%
d = json.loads(response.text)
d
# Out:
# {'Res': {'serviceUrl': 'http://internal-ptkernel-prd-v596-1089980785.us-east-1.elb.amazonaws.com/goroute/CALIFORNIA_NEVADA_W001452_20190719',
#   'Connections': {'valid_until': '2018-09-23',
#    'context': '5VTS3UVTk016ZDwpKPqRTf__AACURl5dEv0C_9AHZAB8T15dEv0',
#    'Connection': [{'id': 'R0034a5-C0',
#      'duration': 'PT41M',
#      'transfers': 1,
#      'Dep': {'time': '2019-08-22T07:36:00',
#       'Addr': {'y': 37.86984, 'x': -122.252232}},
#      'Arr': {'time': '2019-08-22T08:17:00',
#       'Addr': {'y': 37.793212, 'x': -122.396487}},
#      'Sections': {'Sec': [{'id': 'R0034a5-C0-S0',
#         'mode': 20,
#         'Dep': {'time': '2019-08-22T07:36:00',
#          'Addr': {'y': 37.86984, 'x': -122.252232},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 359, 'duration': 'PT06M'},
#         'Arr': {'time': '2019-08-22T07:42:00',
#          'Stn': {'y': 37.868302,
#           'x': -122.25462,
#           'name': 'Durant Av:College Av',
#           'id': '417001310'}}},
#        {'id': 'R0034a5-C0-S1',
#         'mode': 5,
#         'Dep': {'time': '2019-08-22T07:42:00',
#          'Stn': {'y': 37.868302,
#           'x': -122.25462,
#           'name': 'Durant Av:College Av',
#           'id': '417001310'},
#          'Transport': {'mode': 5,
#           'dir': 'Rockridge Bart',
#           'name': '51B',
#           'At': {'category': 'Bus',
#            'color': '#008B59',
#            'textColor': '#FFFFFF',
#            'operator': '42b00100'}},
#          'Freq': {'min': 1,
#           'max': 10,
#           'AltDep': [{'time': '2019-08-22T07:43:00',
#             'Transport': {'mode': 5,
#              'dir': 'Rockridge Bart',
#              'name': '79',
#              'At': {'category': 'Bus', 'operator': '42b00100'}}},
#            {'time': '2019-08-22T07:52:00',
#             'Transport': {'mode': 5,
#              'dir': 'Rockridge Bart',
#              'name': '51B',
#              'At': {'category': 'Bus',
#               'color': '#008B59',
#               'textColor': '#FFFFFF',
#               'operator': '42b00100'}}},
#            {'time': '2019-08-22T08:02:00',
#             'Transport': {'mode': 5,
#              'dir': 'Rockridge Bart',
#              'name': '51B',
#              'At': {'category': 'Bus',
#               'color': '#008B59',
#               'textColor': '#FFFFFF',
#               'operator': '42b00100'}}}]}},
#         'Journey': {'distance': 2366,
#          'duration': 'PT07M',
#          'Stop': [{'dep': '2019-08-22T07:42:00',
#            'Stn': {'y': 37.868302,
#             'x': -122.25462,
#             'name': 'Durant Av:College Av',
#             'id': '417001310'}},
#           {'dep': '2019-08-22T07:43:00',
#            'Stn': {'y': 37.866707,
#             'x': -122.2542,
#             'name': 'College Av:Haste St',
#             'id': '417001241'}},
#           {'dep': '2019-08-22T07:44:00',
#            'Stn': {'y': 37.863357,
#             'x': -122.25375,
#             'name': 'College Av:Parker St',
#             'id': '417005720'}},
#           {'dep': '2019-08-22T07:44:00',
#            'Stn': {'y': 37.861896,
#             'x': -122.25359,
#             'name': 'College Av:Derby St',
#             'id': '417000300'}},
#           {'dep': '2019-08-22T07:45:00',
#            'Stn': {'y': 37.858591,
#             'x': -122.25326,
#             'name': 'College Av:Russell St',
#             'id': '417004286'}},
#           {'dep': '2019-08-22T07:46:00',
#            'Stn': {'y': 37.856824,
#             'x': -122.25311,
#             'name': 'College Av:Ashby Av',
#             'id': '417003396'}},
#           {'dep': '2019-08-22T07:47:00',
#            'Stn': {'y': 37.853701,
#             'x': -122.25282,
#             'name': 'College Av:Woolsey St',
#             'id': '417003723'}},
#           {'dep': '2019-08-22T07:47:00',
#            'Stn': {'y': 37.85093,
#             'x': -122.25256,
#             'name': 'College Av:Alcatraz Av',
#             'id': '417005458'}},
#           {'dep': '2019-08-22T07:48:00',
#            'Stn': {'y': 37.848778,
#             'x': -122.25229,
#             'name': 'College Av:Claremont Av',
#             'id': '417004431'}},
#           {'arr': '2019-08-22T07:49:00',
#            'Stn': {'y': 37.847199,
#             'x': -122.25213,
#             'name': 'College Av:Chabot Rd',
#             'id': '417003551'}}]},
#         'Arr': {'time': '2019-08-22T07:49:00',
#          'Stn': {'y': 37.847199,
#           'x': -122.25213,
#           'name': 'College Av:Chabot Rd',
#           'id': '417003551'}}},
#        {'id': 'R0034a5-C0-S2',
#         'mode': 20,
#         'Dep': {'time': '2019-08-22T07:49:00',
#          'Stn': {'y': 37.847199,
#           'x': -122.25213,
#           'name': 'College Av:Chabot Rd',
#           'id': '417003551'},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 329, 'duration': 'PT07M'},
#         'Arr': {'time': '2019-08-22T07:56:00',
#          'Stn': {'y': 37.844702,
#           'x': -122.25137,
#           'name': 'Rockridge',
#           'id': '718310124'}}},
#        {'id': 'R0034a5-C0-S3',
#         'mode': 7,
#         'Dep': {'time': '2019-08-22T07:56:00',
#          'Stn': {'y': 37.844702,
#           'x': -122.25137,
#           'name': 'Rockridge',
#           'id': '718310124'},
#          'Transport': {'mode': 7,
#           'dir': 'Millbrae',
#           'name': 'Yellow',
#           'At': {'category': 'Train',
#            'color': '#FFFF33',
#            'textColor': '#000000',
#            'operator': '11qBAR00'}},
#          'Freq': {'min': 4,
#           'max': 9,
#           'AltDep': [{'time': '2019-08-22T08:00:00',
#             'Transport': {'mode': 7,
#              'dir': 'Daly City',
#              'name': 'Yellow',
#              'At': {'category': 'Train',
#               'color': '#FFFF33',
#               'textColor': '#000000',
#               'operator': '11qBAR00'}}},
#            {'time': '2019-08-22T08:06:00',
#             'Transport': {'mode': 7,
#              'dir': 'San Francisco International Airport',
#              'name': 'Yellow',
#              'At': {'category': 'Train',
#               'color': '#FFFF33',
#               'textColor': '#000000',
#               'operator': '11qBAR00'}}},
#            {'time': '2019-08-22T08:15:00',
#             'Transport': {'mode': 7,
#              'dir': 'Daly City',
#              'name': 'Yellow',
#              'At': {'category': 'Train',
#               'color': '#FFFF33',
#               'textColor': '#000000',
#               'operator': '11qBAR00'}}}]}},
#         'Journey': {'distance': 17498,
#          'duration': 'PT20M',
#          'Stop': [{'dep': '2019-08-22T07:56:00',
#            'Stn': {'y': 37.844702,
#             'x': -122.25137,
#             'name': 'Rockridge',
#             'id': '718310124'}},
#           {'dep': '2019-08-22T07:59:00',
#            'Stn': {'y': 37.829065,
#             'x': -122.26704,
#             'name': 'MacArthur',
#             'id': '718310113'}},
#           {'dep': '2019-08-22T08:03:00',
#            'Stn': {'y': 37.80835,
#             'x': -122.2686,
#             'name': '19th St. Oakland',
#             'id': '718310094'}},
#           {'dep': '2019-08-22T08:05:00',
#            'Stn': {'y': 37.803768,
#             'x': -122.27145,
#             'name': '12th St. Oakland City Center',
#             'id': '718310093'}},
#           {'dep': '2019-08-22T08:09:00',
#            'Stn': {'y': 37.804872,
#             'x': -122.29514,
#             'name': 'West Oakland',
#             'id': '718310134'}},
#           {'arr': '2019-08-22T08:16:00',
#            'Stn': {'y': 37.792874,
#             'x': -122.39702,
#             'name': 'Embarcadero',
#             'id': '718310106'}}]},
#         'Arr': {'time': '2019-08-22T08:16:00',
#          'Stn': {'y': 37.792874,
#           'x': -122.39702,
#           'name': 'Embarcadero',
#           'id': '718310106'}}},
#        {'id': 'R0034a5-C0-S4',
#         'mode': 20,
#         'Dep': {'time': '2019-08-22T08:16:00',
#          'Stn': {'y': 37.792874,
#           'x': -122.39702,
#           'name': 'Embarcadero',
#           'id': '718310106'},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 61, 'duration': 'PT01M'},
#         'Arr': {'time': '2019-08-22T08:17:00',
#          'Addr': {'y': 37.793212, 'x': -122.396487}}}]},
#      'Tariff': {'Fares': [{'Fare': [{'name': 'Single Ride, Bay Area Rapid Transit',
#           'price': 2.5,
#           'currency': 'USD',
#           'sec_ids': 'R0034a5-C0-S3'}]}]}},
#     {'id': 'R0034a5-C1',
#      'duration': 'PT40M',
#      'transfers': 1,
#      'Dep': {'time': '2019-08-22T07:39:00',
#       'Addr': {'y': 37.86984, 'x': -122.252232}},
#      'Arr': {'time': '2019-08-22T08:19:00',
#       'Addr': {'y': 37.793212, 'x': -122.396487}},
#      'Sections': {'Sec': [{'id': 'R0034a5-C1-S0',
#         'mode': 20,
#         'Dep': {'time': '2019-08-22T07:39:00',
#          'Addr': {'y': 37.86984, 'x': -122.252232},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 290, 'duration': 'PT05M'},
#         'Arr': {'time': '2019-08-22T07:44:00',
#          'Stn': {'y': 37.869294,
#           'x': -122.25512,
#           'name': 'Bancroft Way:College Av',
#           'id': '417005145'}}},
#        {'id': 'R0034a5-C1-S1',
#         'mode': 5,
#         'Dep': {'time': '2019-08-22T07:44:00',
#          'Stn': {'y': 37.869294,
#           'x': -122.25512,
#           'name': 'Bancroft Way:College Av',
#           'id': '417005145'},
#          'Transport': {'mode': 5,
#           'dir': 'Berkeley Amtrak',
#           'name': '51B',
#           'At': {'category': 'Bus',
#            'color': '#008B59',
#            'textColor': '#FFFFFF',
#            'operator': '42b00100'}},
#          'Freq': {'min': 5,
#           'max': 7,
#           'AltDep': [{'time': '2019-08-22T07:51:00',
#             'Transport': {'mode': 5,
#              'dir': 'EL Cerrito Plaza Bart',
#              'name': '79',
#              'At': {'category': 'Bus', 'operator': '42b00100'}}},
#            {'time': '2019-08-22T07:56:00',
#             'Transport': {'mode': 5,
#              'dir': 'Berkeley Amtrak',
#              'name': '51B',
#              'At': {'category': 'Bus',
#               'color': '#008B59',
#               'textColor': '#FFFFFF',
#               'operator': '42b00100'}}}]}},
#         'Journey': {'distance': 1229,
#          'duration': 'PT05M',
#          'Stop': [{'dep': '2019-08-22T07:44:00',
#            'Stn': {'y': 37.869294,
#             'x': -122.25512,
#             'name': 'Bancroft Way:College Av',
#             'id': '417005145'}},
#           {'dep': '2019-08-22T07:45:00',
#            'Stn': {'y': 37.86866,
#             'x': -122.2599,
#             'name': 'Bancroft Way:Telegraph Av',
#             'id': '417005889'}},
#           {'dep': '2019-08-22T07:46:00',
#            'Stn': {'y': 37.868458,
#             'x': -122.26191,
#             'name': 'Bancroft Way:Dana St',
#             'id': '417003047'}},
#           {'dep': '2019-08-22T07:47:00',
#            'Stn': {'y': 37.868169,
#             'x': -122.26408,
#             'name': 'Bancroft Way:Ellsworth St',
#             'id': '417002406'}},
#           {'arr': '2019-08-22T07:49:00',
#            'Stn': {'y': 37.869119,
#             'x': -122.2677,
#             'name': 'Shattuck Av:Allston Way (Transit Hub)',
#             'id': '417006009'}}]},
#         'Arr': {'time': '2019-08-22T07:49:00',
#          'Stn': {'y': 37.869119,
#           'x': -122.2677,
#           'name': 'Shattuck Av:Allston Way (Transit Hub)',
#           'id': '417006009'}}},
#        {'id': 'R0034a5-C1-S2',
#         'mode': 20,
#         'Dep': {'time': '2019-08-22T07:49:00',
#          'Stn': {'y': 37.869119,
#           'x': -122.2677,
#           'name': 'Shattuck Av:Allston Way (Transit Hub)',
#           'id': '417006009'},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 131, 'duration': 'PT04M'},
#         'Arr': {'time': '2019-08-22T07:53:00',
#          'Stn': {'y': 37.870104,
#           'x': -122.26813,
#           'name': 'Downtown Berkeley',
#           'id': '718310103'}}},
#        {'id': 'R0034a5-C1-S3',
#         'mode': 7,
#         'Dep': {'time': '2019-08-22T07:55:00',
#          'Stn': {'y': 37.870104,
#           'x': -122.26813,
#           'name': 'Downtown Berkeley',
#           'id': '718310103'},
#          'Transport': {'mode': 7,
#           'dir': 'Millbrae',
#           'name': 'Red',
#           'At': {'category': 'Train',
#            'color': '#FF0000',
#            'textColor': '#FFFFFF',
#            'operator': '11qBAR00'}},
#          'Freq': {'min': 15,
#           'max': 15,
#           'AltDep': [{'time': '2019-08-22T08:10:00',
#             'Transport': {'mode': 7,
#              'dir': 'Millbrae',
#              'name': 'Red',
#              'At': {'category': 'Train',
#               'color': '#FF0000',
#               'textColor': '#FFFFFF',
#               'operator': '11qBAR00'}}}]}},
#         'Journey': {'distance': 19716,
#          'duration': 'PT23M',
#          'Stop': [{'dep': '2019-08-22T07:55:00',
#            'Stn': {'y': 37.870104,
#             'x': -122.26813,
#             'name': 'Downtown Berkeley',
#             'id': '718310103'}},
#           {'dep': '2019-08-22T07:57:00',
#            'Stn': {'y': 37.852803,
#             'x': -122.27006,
#             'name': 'Ashby',
#             'id': '718310097'}},
#           {'dep': '2019-08-22T08:01:00',
#            'Stn': {'y': 37.829065,
#             'x': -122.26704,
#             'name': 'MacArthur',
#             'id': '718310113'}},
#           {'dep': '2019-08-22T08:05:00',
#            'Stn': {'y': 37.80835,
#             'x': -122.2686,
#             'name': '19th St. Oakland',
#             'id': '718310094'}},
#           {'dep': '2019-08-22T08:06:00',
#            'Stn': {'y': 37.803768,
#             'x': -122.27145,
#             'name': '12th St. Oakland City Center',
#             'id': '718310093'}},
#           {'dep': '2019-08-22T08:11:00',
#            'Stn': {'y': 37.804872,
#             'x': -122.29514,
#             'name': 'West Oakland',
#             'id': '718310134'}},
#           {'arr': '2019-08-22T08:18:00',
#            'Stn': {'y': 37.792874,
#             'x': -122.39702,
#             'name': 'Embarcadero',
#             'id': '718310106'}}]},
#         'Arr': {'time': '2019-08-22T08:18:00',
#          'Stn': {'y': 37.792874,
#           'x': -122.39702,
#           'name': 'Embarcadero',
#           'id': '718310106'}}},
#        {'id': 'R0034a5-C1-S4',
#         'mode': 20,
#         'Dep': {'time': '2019-08-22T08:18:00',
#          'Stn': {'y': 37.792874,
#           'x': -122.39702,
#           'name': 'Embarcadero',
#           'id': '718310106'},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 61, 'duration': 'PT01M'},
#         'Arr': {'time': '2019-08-22T08:19:00',
#          'Addr': {'y': 37.793212, 'x': -122.396487}}}]},
#      'Tariff': {'Fares': [{'Fare': [{'name': 'Single Ride, Bay Area Rapid Transit',
#           'price': 2.5,
#           'currency': 'USD',
#           'sec_ids': 'R0034a5-C1-S3'}]}]}},
#     {'id': 'R0034a5-C2',
#      'duration': 'PT42M',
#      'transfers': 1,
#      'Dep': {'time': '2019-08-22T07:39:00',
#       'Addr': {'y': 37.86984, 'x': -122.252232}},
#      'Arr': {'time': '2019-08-22T08:21:00',
#       'Addr': {'y': 37.793212, 'x': -122.396487}},
#      'Sections': {'Sec': [{'id': 'R0034a5-C2-S0',
#         'mode': 20,
#         'Dep': {'time': '2019-08-22T07:39:00',
#          'Addr': {'y': 37.86984, 'x': -122.252232},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 280, 'duration': 'PT05M'},
#         'Arr': {'time': '2019-08-22T07:44:00',
#          'Stn': {'y': 37.867478,
#           'x': -122.25199,
#           'name': 'Piedmont Av:Channing Way',
#           'id': '417000036'}}},
#        {'id': 'R0034a5-C2-S1',
#         'mode': 5,
#         'Dep': {'time': '2019-08-22T07:44:00',
#          'Stn': {'y': 37.867478,
#           'x': -122.25199,
#           'name': 'Piedmont Av:Channing Way',
#           'id': '417000036'},
#          'Transport': {'mode': 5,
#           'dir': 'Rockridge Bart',
#           'name': '79',
#           'At': {'category': 'Bus', 'operator': '42b00100'}}},
#         'Journey': {'distance': 2908,
#          'duration': 'PT08M',
#          'Stop': [{'dep': '2019-08-22T07:44:00',
#            'Stn': {'y': 37.867478,
#             'x': -122.25199,
#             'name': 'Piedmont Av:Channing Way',
#             'id': '417000036'}},
#           {'dep': '2019-08-22T07:45:00',
#            'Stn': {'y': 37.865983,
#             'x': -122.25141,
#             'name': 'Piedmont Av:Dwight Way',
#             'id': '417001103'}},
#           {'dep': '2019-08-22T07:46:00',
#            'Stn': {'y': 37.864243,
#             'x': -122.25039,
#             'name': 'Warring St:Parker St',
#             'id': '417004977'}},
#           {'dep': '2019-08-22T07:46:00',
#            'Stn': {'y': 37.862456,
#             'x': -122.2502,
#             'name': 'Warring St:Derby St',
#             'id': '417002451'}},
#           {'dep': '2019-08-22T07:47:00',
#            'Stn': {'y': 37.862424,
#             'x': -122.24728,
#             'name': 'Derby St:Claremont Blvd',
#             'id': '417004866'}},
#           {'dep': '2019-08-22T07:48:00',
#            'Stn': {'y': 37.860505,
#             'x': -122.24563,
#             'name': 'Claremont Blvd:Garber St',
#             'id': '417000867'}},
#           {'dep': '2019-08-22T07:49:00',
#            'Stn': {'y': 37.858197,
#             'x': -122.24534,
#             'name': 'Claremont Av:Ashby Av',
#             'id': '417004840'}},
#           {'dep': '2019-08-22T07:49:00',
#            'Stn': {'y': 37.856225,
#             'x': -122.24692,
#             'name': 'Claremont Av:Webster St',
#             'id': '417003195'}},
#           {'dep': '2019-08-22T07:50:00',
#            'Stn': {'y': 37.854115,
#             'x': -122.24862,
#             'name': 'Claremont Av:Woolsey St',
#             'id': '417003196'}},
#           {'dep': '2019-08-22T07:51:00',
#            'Stn': {'y': 37.852445,
#             'x': -122.24997,
#             'name': 'Claremont Av:Eton Av',
#             'id': '417004058'}},
#           {'dep': '2019-08-22T07:51:00',
#            'Stn': {'y': 37.850753,
#             'x': -122.25137,
#             'name': 'Claremont Av:Mystic St',
#             'id': '417005830'}},
#           {'dep': '2019-08-22T07:52:00',
#            'Stn': {'y': 37.848778,
#             'x': -122.25229,
#             'name': 'College Av:Claremont Av',
#             'id': '417004431'}},
#           {'arr': '2019-08-22T07:52:00',
#            'Stn': {'y': 37.847199,
#             'x': -122.25213,
#             'name': 'College Av:Chabot Rd',
#             'id': '417003551'}}]},
#         'Arr': {'time': '2019-08-22T07:52:00',
#          'Stn': {'y': 37.847199,
#           'x': -122.25213,
#           'name': 'College Av:Chabot Rd',
#           'id': '417003551'}}},
#        {'id': 'R0034a5-C2-S2',
#         'mode': 20,
#         'Dep': {'time': '2019-08-22T07:52:00',
#          'Stn': {'y': 37.847199,
#           'x': -122.25213,
#           'name': 'College Av:Chabot Rd',
#           'id': '417003551'},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 329, 'duration': 'PT07M'},
#         'Arr': {'time': '2019-08-22T07:59:00',
#          'Stn': {'y': 37.844702,
#           'x': -122.25137,
#           'name': 'Rockridge',
#           'id': '718310124'}}},
#        {'id': 'R0034a5-C2-S3',
#         'mode': 7,
#         'Dep': {'time': '2019-08-22T08:00:00',
#          'Stn': {'y': 37.844702,
#           'x': -122.25137,
#           'name': 'Rockridge',
#           'id': '718310124'},
#          'Transport': {'mode': 7,
#           'dir': 'Daly City',
#           'name': 'Yellow',
#           'At': {'category': 'Train',
#            'color': '#FFFF33',
#            'textColor': '#000000',
#            'operator': '11qBAR00'}},
#          'Freq': {'min': 6,
#           'max': 9,
#           'AltDep': [{'time': '2019-08-22T08:06:00',
#             'Transport': {'mode': 7,
#              'dir': 'San Francisco International Airport',
#              'name': 'Yellow',
#              'At': {'category': 'Train',
#               'color': '#FFFF33',
#               'textColor': '#000000',
#               'operator': '11qBAR00'}}},
#            {'time': '2019-08-22T08:15:00',
#             'Transport': {'mode': 7,
#              'dir': 'Daly City',
#              'name': 'Yellow',
#              'At': {'category': 'Train',
#               'color': '#FFFF33',
#               'textColor': '#000000',
#               'operator': '11qBAR00'}}}]}},
#         'Journey': {'distance': 17498,
#          'duration': 'PT20M',
#          'Stop': [{'dep': '2019-08-22T08:00:00',
#            'Stn': {'y': 37.844702,
#             'x': -122.25137,
#             'name': 'Rockridge',
#             'id': '718310124'}},
#           {'dep': '2019-08-22T08:03:00',
#            'Stn': {'y': 37.829065,
#             'x': -122.26704,
#             'name': 'MacArthur',
#             'id': '718310113'}},
#           {'dep': '2019-08-22T08:07:00',
#            'Stn': {'y': 37.80835,
#             'x': -122.2686,
#             'name': '19th St. Oakland',
#             'id': '718310094'}},
#           {'dep': '2019-08-22T08:09:00',
#            'Stn': {'y': 37.803768,
#             'x': -122.27145,
#             'name': '12th St. Oakland City Center',
#             'id': '718310093'}},
#           {'dep': '2019-08-22T08:13:00',
#            'Stn': {'y': 37.804872,
#             'x': -122.29514,
#             'name': 'West Oakland',
#             'id': '718310134'}},
#           {'arr': '2019-08-22T08:20:00',
#            'Stn': {'y': 37.792874,
#             'x': -122.39702,
#             'name': 'Embarcadero',
#             'id': '718310106'}}]},
#         'Arr': {'time': '2019-08-22T08:20:00',
#          'Stn': {'y': 37.792874,
#           'x': -122.39702,
#           'name': 'Embarcadero',
#           'id': '718310106'}}},
#        {'id': 'R0034a5-C2-S4',
#         'mode': 20,
#         'Dep': {'time': '2019-08-22T08:20:00',
#          'Stn': {'y': 37.792874,
#           'x': -122.39702,
#           'name': 'Embarcadero',
#           'id': '718310106'},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 61, 'duration': 'PT01M'},
#         'Arr': {'time': '2019-08-22T08:21:00',
#          'Addr': {'y': 37.793212, 'x': -122.396487}}}]},
#      'Tariff': {'Fares': [{'Fare': [{'name': 'Single Ride, Bay Area Rapid Transit',
#           'price': 2.5,
#           'currency': 'USD',
#           'sec_ids': 'R0034a5-C2-S3'}]}]}},
#     {'id': 'R0034a4-C0',
#      'duration': 'PT0H30M49S',
#      'transfers': 0,
#      'Dep': {'time': '2019-08-22T07:35:00',
#       'Addr': {'x': -122.2522441, 'y': 37.8698381},
#       'Activities': {'Act': [{'type': 'wait', 'duration': 'PT0H5M0S'}]}},
#      'Arr': {'time': '2019-08-22T08:00:49',
#       'RT': {'arr': '2019-08-22T08:22:27'},
#       'Addr': {'x': -122.3964403, 'y': 37.7931761}},
#      'Sections': {'Sec': [{'mode': 23,
#         'id': 'R0034a4-C0-S0',
#         'Dep': {'time': '2019-08-22T07:35:00',
#          'Addr': {'x': -122.2522441, 'y': 37.8698381},
#          'Transport': {'mode': 23,
#           'At': {'operator': 'local_taxi',
#            'category': 'Taxi',
#            'color': '#FECC00'}},
#          'Activities': {'Act': [{'type': 'wait', 'duration': 'PT0H5M0S'}]}},
#         'Journey': {'distance': 20176, 'duration': 'PT0H25M49S'},
#         'Arr': {'time': '2019-08-22T08:00:49',
#          'RT': {'arr': '2019-08-22T08:22:27'},
#          'Addr': {'x': -122.3964403, 'y': 37.7931761}}}]},
#      'Tariff': {'Fares': [{'Fare': [{'name': 'Taxi fare',
#           'currency': 'USD',
#           'sec_ids': 'R0034a4-C0-S0',
#           'price': 41.0,
#           'estimated': 1}]}]}},
#     {'transfers': 0,
#      'duration': 'PT0H36M16S',
#      'id': 'R0034a6-C0',
#      'Dep': {'time': '2019-08-22T07:30:00',
#       'Addr': {'x': -122.2522545, 'y': 37.8698838}},
#      'Arr': {'time': '2019-08-22T08:04:16',
#       'RT': {'arr': '2019-08-22T08:25:48'},
#       'Addr': {'x': -122.3964403, 'y': 37.7931761},
#       'Activities': {'Act': [{'type': 'parking', 'duration': 'PT0H2M0S'}]}},
#      'Sections': {'Sec': [{'mode': 20,
#         'id': 'R0034a6-C0-S0',
#         'Dep': {'time': '2019-08-22T07:30:00',
#          'Addr': {'x': -122.2522545, 'y': 37.8698838},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 453, 'duration': 'PT0H7M56S'},
#         'Arr': {'time': '2019-08-22T07:37:56',
#          'Addr': {'x': -122.2544003, 'y': 37.8674698}}},
#        {'mode': 22,
#         'id': 'R0034a6-C0-S1',
#         'Dep': {'time': '2019-08-22T07:40:56',
#          'Addr': {'x': -122.2544516,
#           'y': 37.8674622,
#           'name': '2690 Channing Way'},
#          'Transport': {'mode': 22,
#           'At': {'category': 'CarShare',
#            'color': '#4FA600',
#            'model': 'Honda Civic Hatchback',
#            'operator': 'zipcar'},
#           'Link': [{'href': 'https://mobility.api.here.com/r?appId=Pt3AjURCavWv8DLkK9KX&u=http://media.zipcar.com/images/model-image?model_id=2738038734',
#             'type': 'productIcon'}]},
#          'Activities': {'Act': [{'type': 'setup', 'duration': 'PT0H3M0S'}]}},
#         'Journey': {'distance': 19364, 'duration': 'PT0H23M20S'},
#         'Arr': {'time': '2019-08-22T08:04:16',
#          'RT': {'arr': '2019-08-22T08:25:48'},
#          'Addr': {'x': -122.3964403, 'y': 37.7931761},
#          'Activities': {'Act': [{'type': 'parking',
#             'duration': 'PT0H2M0S'}]}}}]},
#      'Tariff': {'Fares': [{'Fare': [{'name': 'Zipcar hourly rate',
#           'currency': 'USD',
#           'sec_ids': 'R0034a6-C0-S1',
#           'type': 'hourly',
#           'price': 7.5}]},
#        {'Fare': [{'name': 'Zipcar daily rate',
#           'currency': 'USD',
#           'sec_ids': 'R0034a6-C0-S1',
#           'type': 'daily',
#           'price': 69.0}]}]}},
#     {'transfers': 0,
#      'duration': 'PT0H36M16S',
#      'id': 'R0034a6-C1',
#      'Dep': {'time': '2019-08-22T07:30:00',
#       'Addr': {'x': -122.2522545, 'y': 37.8698838}},
#      'Arr': {'time': '2019-08-22T08:04:16',
#       'RT': {'arr': '2019-08-22T08:25:48'},
#       'Addr': {'x': -122.3964403, 'y': 37.7931761},
#       'Activities': {'Act': [{'type': 'parking', 'duration': 'PT0H2M0S'}]}},
#      'Sections': {'Sec': [{'mode': 20,
#         'id': 'R0034a6-C1-S0',
#         'Dep': {'time': '2019-08-22T07:30:00',
#          'Addr': {'x': -122.2522545, 'y': 37.8698838},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 453, 'duration': 'PT0H7M56S'},
#         'Arr': {'time': '2019-08-22T07:37:56',
#          'Addr': {'x': -122.2544003, 'y': 37.8674698}}},
#        {'mode': 22,
#         'id': 'R0034a6-C1-S1',
#         'Dep': {'time': '2019-08-22T07:40:56',
#          'Addr': {'x': -122.2544516,
#           'y': 37.8674622,
#           'name': '2690 Channing Way'},
#          'Transport': {'mode': 22,
#           'At': {'category': 'CarShare',
#            'color': '#4FA600',
#            'model': 'Honda CR-V',
#            'operator': 'zipcar'},
#           'Link': [{'href': 'https://mobility.api.here.com/r?appId=Pt3AjURCavWv8DLkK9KX&u=http://media.zipcar.com/images/model-image?model_id=64790058',
#             'type': 'productIcon'}]},
#          'Activities': {'Act': [{'type': 'setup', 'duration': 'PT0H3M0S'}]}},
#         'Journey': {'distance': 19364, 'duration': 'PT0H23M20S'},
#         'Arr': {'time': '2019-08-22T08:04:16',
#          'RT': {'arr': '2019-08-22T08:25:48'},
#          'Addr': {'x': -122.3964403, 'y': 37.7931761},
#          'Activities': {'Act': [{'type': 'parking',
#             'duration': 'PT0H2M0S'}]}}}]},
#      'Tariff': {'Fares': [{'Fare': [{'name': 'Zipcar hourly rate',
#           'currency': 'USD',
#           'sec_ids': 'R0034a6-C1-S1',
#           'type': 'hourly',
#           'price': 8.5}]},
#        {'Fare': [{'name': 'Zipcar daily rate',
#           'currency': 'USD',
#           'sec_ids': 'R0034a6-C1-S1',
#           'type': 'daily',
#           'price': 77.0}]}]}},
#     {'transfers': 0,
#      'duration': 'PT0H44M54S',
#      'id': 'R0034a6-C2',
#      'Dep': {'time': '2019-08-22T07:30:00',
#       'Addr': {'x': -122.2522545, 'y': 37.8698838}},
#      'Arr': {'time': '2019-08-22T08:12:54',
#       'RT': {'arr': '2019-08-22T08:35:12'},
#       'Addr': {'x': -122.3964403, 'y': 37.7931761},
#       'Activities': {'Act': [{'type': 'parking', 'duration': 'PT0H2M0S'}]}},
#      'Sections': {'Sec': [{'mode': 20,
#         'id': 'R0034a6-C2-S0',
#         'Dep': {'time': '2019-08-22T07:30:00',
#          'Addr': {'x': -122.2522545, 'y': 37.8698838},
#          'Transport': {'mode': 20}},
#         'Journey': {'distance': 743, 'duration': 'PT0H12M44S'},
#         'Arr': {'time': '2019-08-22T07:42:44',
#          'Addr': {'x': -122.2548938, 'y': 37.8755057}}},
#        {'mode': 22,
#         'id': 'R0034a6-C2-S1',
#         'Dep': {'time': '2019-08-22T07:45:44',
#          'Addr': {'x': -122.2548427,
#           'y': 37.8754829,
#           'name': '1317 Cyclotron Road'},
#          'Transport': {'mode': 22,
#           'At': {'category': 'CarShare',
#            'color': '#4FA600',
#            'model': 'Honda CR-V',
#            'operator': 'zipcar'},
#           'Link': [{'href': 'https://mobility.api.here.com/r?appId=Pt3AjURCavWv8DLkK9KX&u=http://media.zipcar.com/images/model-image?model_id=64790058',
#             'type': 'productIcon'}]},
#          'Activities': {'Act': [{'type': 'setup', 'duration': 'PT0H3M0S'}]}},
#         'Journey': {'distance': 20725, 'duration': 'PT0H27M10S'},
#         'Arr': {'time': '2019-08-22T08:12:54',
#          'RT': {'arr': '2019-08-22T08:35:12'},
#          'Addr': {'x': -122.3964403, 'y': 37.7931761},
#          'Activities': {'Act': [{'type': 'parking',
#             'duration': 'PT0H2M0S'}]}}}]},
#      'Tariff': {'Fares': [{'Fare': [{'name': 'Zipcar hourly rate',
#           'currency': 'USD',
#           'sec_ids': 'R0034a6-C2-S1',
#           'type': 'hourly',
#           'price': 8.5}]},
#        {'Fare': [{'name': 'Zipcar daily rate',
#           'currency': 'USD',
#           'sec_ids': 'R0034a6-C2-S1',
#           'type': 'daily',
#           'price': 77.0}]}]}}],
#    'Operators': {'Op': [{'code': '42b00100',
#       'type': 'TT',
#       'name': 'AC Transit',
#       'short_name': '1',
#       'Link': [{'type': 'website',
#         'href': 'https://mobility.api.here.com/r?appId=Pt3AjURCavWv8DLkK9KX&u=http://www.actransit.org',
#         'sec_ids': 'R0034a5-C0-S1 R0034a5-C1-S1 R0034a5-C2-S1',
#         'text': 'AC Transit'}],
#       'At': {'phone': '(510)891-4777'}},
#      {'code': '11qBAR00',
#       'type': 'TT',
#       'name': 'BART',
#       'short_name': 'BAR',
#       'Link': [{'type': 'website',
#         'href': 'https://mobility.api.here.com/r?appId=Pt3AjURCavWv8DLkK9KX&u=http://www.bart.gov',
#         'sec_ids': 'R0034a5-C0-S3 R0034a5-C1-S3 R0034a5-C2-S3',
#         'text': 'BART'}]},
#      {'name': 'Berkeley Yellow Cab (Yellow Express Cab)',
#       'code': 'local_taxi',
#       'Link': [{'type': 'website',
#         'href': 'https://mobility.api.here.com/r?appId=Pt3AjURCavWv8DLkK9KX&u=http://www.yellowexpresscab.net',
#         'sec_ids': 'R0034a4-C0-S0',
#         'text': 'http://www.yellowexpresscab.net'}],
#       'At': {'phone': '+15105289999'}},
#      {'name': 'Zipcar',
#       'code': 'zipcar',
#       'Link': [{'type': 'website',
#         'href': 'https://mobility.api.here.com/r?appId=Pt3AjURCavWv8DLkK9KX&u=https://www.zipcar.com',
#         'sec_ids': 'R0034a6-C0-S1 R0034a6-C1-S1 R0034a6-C2-S1',
#         'text': 'https://www.zipcar.com'}]}]}}}}
